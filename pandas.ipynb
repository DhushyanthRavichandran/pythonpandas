# %% [markdown]
# <a href="https://colab.research.google.com/github/DhushyanthRavichandran/pythonpandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# separation of row and col so that we call it as dataframes.....
# col names in pandas............
# all type of datatypes in one data frame............
# numpy access only by indexes ..........
# panda access row col colindex row index......
# cpu->vram->videoram,multithreading
# tpu->tensor processing unit->
# parallelism->gpu

# %%
import pandas as pd
import numpy as np

# %%
a=np.array([10,1,2,4,5,6,7])
type(a)
a[2]
# Out:
# 2

# %%
s=np.array([10,1,2,4,5,6,7])
#type(s)

# %%
s.drop(3,inplace=True) #removing both index and its value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-352808a83f09> in <cell line: 1>()
# ----> 1 s.drop(3,inplace=True) #removing both index and its value
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'

# %%
s
# Out:
# array([10,  1,  2,  4,  5,  6,  7])

# %%
s.iloc[3] #to acces the element we use the index value for iloc for index right column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-6b0968dfe6b9> in <cell line: 1>()
# ----> 1 s.iloc[3] #to acces the element we use the index value for iloc for index right column
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
#s.loc[3] #it uses the left column value

# %%
s.loc[5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-431b6e2e012c> in <cell line: 1>()
# ----> 1 s.loc[5]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'loc'

# %%
s.index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-618a1b6df4c9> in <cell line: 1>()
# ----> 1 s.index
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
ss=pd.Series([10,12,13,14,15,16],index=['dhush','andrew','jeevagan','b','c','b'])
ss

# %%
ss.loc['b']

# %%
ss.iloc[3]

# %%
data=[['dhush',10,'23-02-2004'],['andrew',19,'22-02-2004'],['jeevagan',20,'11-11-2004']]
data
# Out:
# [['dhush', 10, '23-02-2004'],
#  ['andrew', 19, '22-02-2004'],
#  ['jeevagan', 20, '11-11-2004']]

# %%
df=pd.DataFrame([data]) #1D
df
# Out:
#                          0                         1  \
# 0  [dhush, 10, 23-02-2004]  [andrew, 19, 22-02-2004]
#
#                             2
# 0  [jeevagan, 20, 11-11-2004]

# %%
df=pd.DataFrame(data)
df
# Out:
#           0   1           2
# 0     dhush  10  23-02-2004
# 1    andrew  19  22-02-2004
# 2  jeevagan  20  11-11-2004

# %%
df[:2]
# Out:
#         0   1           2
# 0   dhush  10  23-02-2004
# 1  andrew  19  22-02-2004

# %%
df[[0,1]]#specific column 0 and 1 column
# Out:
#           0   1
# 0     dhush  10
# 1    andrew  19
# 2  jeevagan  20

# %%
df[0][1]
# Out:
# 'andrew'

# %%
df=pd.DataFrame(data,columns=['firstname','age','dob'])
df
# Out:
#   firstname  age         dob
# 0     dhush   10  23-02-2004
# 1    andrew   19  22-02-2004
# 2  jeevagan   20  11-11-2004

# %%
df['firstname']
# Out:
# 0       dhush
# 1      andrew
# 2    jeevagan
# Name: firstname, dtype: object

# %%
df['firstname'][1]
# Out:
# 'andrew'

# %% [markdown]
# df.loc[0,'firstname']

# %%
df.iloc[1,0] #if we use 1,0 then row=1,column=0
# Out:
# 'andrew'

# %%
df['firstname'][0]
# Out:
# 'dhush'

# %%
df.iloc[0] #first row
# Out:
# firstname         dhush
# age                  10
# dob          23-02-2004
# Name: 0, dtype: object

# %%
df[0:1] #first rowmmm
# Out:
#   firstname  age         dob
# 0     dhush   10  23-02-2004

# %%
s=pd.Series([11,34,11,25,86,78])
s
# Out:
# 0    11
# 1    34
# 2    11
# 3    25
# 4    86
# 5    78
# dtype: int64

# %%
s.plot()
# Out:
# <Axes: >

# %%
s.hist(bins=2)
# Out:
# <Axes: >

# %%
s=s.to_numpy()
type(s)
# Out:
# numpy.ndarray

# %%
df
# Out:
#   firstname  age         dob
# 0     dhush   10  23-02-2004
# 1    andrew   19  22-02-2004
# 2  jeevagan   20  11-11-2004

# %%
df.head()
# Out:
#   firstname  age         dob
# 0     dhush   10  23-02-2004
# 1    andrew   19  22-02-2004
# 2  jeevagan   20  11-11-2004

# %%
df.head(2)
# Out:
#   firstname  age         dob
# 0     dhush   10  23-02-2004
# 1    andrew   19  22-02-2004

# %%
df.tail()
# Out:
#   firstname  age         dob
# 0     dhush   10  23-02-2004
# 1    andrew   19  22-02-2004
# 2  jeevagan   20  11-11-2004

# %%
df.tail(2)
# Out:
#   firstname  age         dob
# 1    andrew   19  22-02-2004
# 2  jeevagan   20  11-11-2004

# %%
df.tail(-2)
# Out:
#   firstname  age         dob
# 2  jeevagan   20  11-11-2004

# %%
df.tail(-1)
# Out:
#   firstname  age         dob
# 1    andrew   19  22-02-2004
# 2  jeevagan   20  11-11-2004

# %% [markdown]
# # None,' ','','-','?','Nil',np.nan ->not a number:

# %%
data=[['dhush',10,'23-02-2004'],['andrew',19,None],['jeevagan',np.nan,'11-11-2004'],['adish',19,'1-03-2004'],['deepak',None,np.nan],['dhivakar','99','2-09-1999']]
df=pd.DataFrame(data)
df
# Out:
#           0     1           2
# 0     dhush    10  23-02-2004
# 1    andrew    19        None
# 2  jeevagan   NaN  11-11-2004
# 3     adish    19   1-03-2004
# 4    deepak  None         NaN
# 5  dhivakar    99   2-09-1999

# %%
df.isnull()
# Out:
#        0      1      2
# 0  False  False  False
# 1  False  False   True
# 2  False   True  False
# 3  False  False  False
# 4  False   True   True
# 5  False  False  False

# %%
df.isnull().sum() #showing the column of sum of nan value in right hand side
# Out:
# 0    0
# 1    2
# 2    2
# dtype: int64

# %%
df.isnull().count()
# Out:
# 0    6
# 1    6
# 2    6
# dtype: int64

# %%
df.dropna(inplace=True) #if there is none or nan in matrix then  that total row will be removed

# %%
df
# Out:
#           0   1           2
# 0     dhush  10  23-02-2004
# 3     adish  19   1-03-2004
# 5  dhivakar  99   2-09-1999

# %%
data=[['dhush',10,'23-02-2004'],['andrew',19,None],['jeevagan',np.nan,'11-11-2004'],['adish',19,'1-03-2004'],['deepak',None,np.nan],['dhivakar','99','2-09-1999']]
df=pd.DataFrame(data)
df=pd.DataFrame(data,columns=['firstname','age','dob'])
df
# Out:
#   firstname   age         dob
# 0     dhush    10  23-02-2004
# 1    andrew    19        None
# 2  jeevagan   NaN  11-11-2004
# 3     adish    19   1-03-2004
# 4    deepak  None         NaN
# 5  dhivakar    99   2-09-1999

# %%
df.dropna()
# Out:
#   firstname age         dob
# 0     dhush  10  23-02-2004
# 3     adish  19   1-03-2004
# 5  dhivakar  99   2-09-1999

# %%
df.drop(['age'],axis=1)
# Out:
#   firstname         dob
# 0     dhush  23-02-2004
# 1    andrew        None
# 2  jeevagan  11-11-2004
# 3     adish   1-03-2004
# 4    deepak         NaN
# 5  dhivakar   2-09-1999

# %%
df.drop([0,2])   #delete the 0 and 2 nd row
# Out:
#   firstname   age        dob
# 1    andrew    19       None
# 3     adish    19  1-03-2004
# 4    deepak  None        NaN
# 5  dhivakar    99  2-09-1999

# %%
df.drop(['firstname','dob'],axis=1)
# Out:
#     age
# 0    10
# 1    19
# 2   NaN
# 3    19
# 4  None
# 5    99

# %%
a
# Out:
# array([10,  1,  2,  4,  5,  6,  7])

# %%
a>2
# Out:
# array([ True, False, False,  True,  True,  True,  True])

# %%
a[a>2]
# Out:
# array([10,  4,  5,  6,  7])

# %%
a[a%2!=0]
# Out:
# array([1, 5, 7])

# %%
a[a%2==0]
# Out:
# array([10,  2,  4,  6])

# %%
df
# Out:
#   firstname   age         dob
# 0     dhush    10  23-02-2004
# 1    andrew    19        None
# 2  jeevagan   NaN  11-11-2004
# 3     adish    19   1-03-2004
# 4    deepak  None         NaN
# 5  dhivakar    99   2-09-1999

# %%
df.info
# Out:
# <bound method DataFrame.info of   firstname   age         dob
# 0     dhush    10  23-02-2004
# 1    andrew    19        None
# 2  jeevagan   NaN  11-11-2004
# 3     adish    19   1-03-2004
# 4    deepak  None         NaN
# 5  dhivakar    99   2-09-1999>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   firstname  6 non-null      object
#  1   age        4 non-null      object
#  2   dob        4 non-null      object
# dtypes: object(3)
# memory usage: 272.0+ bytes

# %%
df['firstname'].str.contains('e')
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# Name: firstname, dtype: bool

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (6, 3)
# 18
# [RangeIndex(start=0, stop=6, step=1), Index(['firstname', 'age', 'dob'], dtype='object')]
# firstname    object
# age          object
# dob          object
# dtype: object
# RangeIndex(start=0, stop=6, step=1)
# Index(['firstname', 'age', 'dob'], dtype='object')
# [['dhush' 10 '23-02-2004']
#  ['andrew' 19 None]
#  ['jeevagan' nan '11-11-2004']
#  ['adish' 19 '1-03-2004']
#  ['deepak' None nan]
#  ['dhivakar' '99' '2-09-1999']]

# %%
df.head() #displays n-1 values
# Out:
#   firstname   age         dob
# 0     dhush    10  23-02-2004
# 1    andrew    19        None
# 2  jeevagan   NaN  11-11-2004
# 3     adish    19   1-03-2004
# 4    deepak  None         NaN

# %%
df.tail()
# Out:
#   firstname   age         dob
# 1    andrew    19        None
# 2  jeevagan   NaN  11-11-2004
# 3     adish    19   1-03-2004
# 4    deepak  None         NaN
# 5  dhivakar    99   2-09-1999

# %%
pd.concat([df,df])
# Out:
#   firstname   age         dob
# 0     dhush    10  23-02-2004
# 1    andrew    19        None
# 2  jeevagan   NaN  11-11-2004
# 3     adish    19   1-03-2004
# 4    deepak  None         NaN
# 5  dhivakar    99   2-09-1999
# 0     dhush    10  23-02-2004
# 1    andrew    19        None
# 2  jeevagan   NaN  11-11-2004
# 3     adish    19   1-03-2004
# 4    deepak  None         NaN
# 5  dhivakar    99   2-09-1999

# %%
df.describe()
# Out:
#        firstname  age         dob
# count          6    4           4
# unique         6    3           4
# top        dhush   19  23-02-2004
# freq           1    2           1

# %%
df.dob
# Out:
# 0    23-02-2004
# 1          None
# 2    11-11-2004
# 3     1-03-2004
# 4           NaN
# 5     2-09-1999
# Name: dob, dtype: object

# %%
df.dob[0]
# Out:
# '23-02-2004'

# %%
df.loc[0,'firstname']
# Out:
# 'dhush'

# %%
df.loc[0][0]  #all the thing that iloc do can alsi be done by the loc which is it can also uses index values
# Out:
# 'dhush'

# %%
 #df.loc[0][0]='hi'
  #df

# %%
df.iloc[1]
# Out:
# firstname    andrew
# age              19
# dob            None
# Name: 1, dtype: object

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/Vijay_filmography")
type(df)
# Out:
# list

# %%
df
# Out:
# [   0                                              1
#  0  †  Denotes films that have not yet been released,
#      Year                  Title                      Role(s)  \
#  0   1984                  Vetri                        Vijay
#  1   1984               Kudumbam                       Narada
#  2   1985  Naan Sigappu Manithan                     Un­known
#  3   1986        Vasantha Raagam                        Vijay
#  4   1987  Sattam Oru Vilaiyattu                         Raja
#  ..   ...                    ...                          ...
#  71  2021                 Master           John Durairaj (JD)
#  72  2022                  Beast               Veera Raghavan
#  73  2023                 Varisu              Vijay Rajendran
#  74  2023                  Leo †  Leo Das/ Parthiban (Parthi)
#  75  2024        Thalapathy 68 †                          TBA
#
#                                              Notes  \
#  0                                    Child artist
# ...

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
#df.describe()
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")

type(df.item_price[0])
# Out:
# str

# %%
df.item_price
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df.item_price=df.item_price.str.replace('$','')
df.item_price
# Out:
# <ipython-input-153-7b6778b66c48>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price=df.item_price.str.replace('$','')
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df.item_price=df.item_price.astype(float)
type(item_price[0])
# Out:
# str

# %%
#df.item_price=df.item_price*100
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df.item_name.unique
# Out:
# <bound method Series.unique of 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object>

# %%
df_drink=df[df.item_price<1.1]
df_drink
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
df_drink.item_name.unique()
# Out:
# array(['Canned Soda', 'Bottled Water'], dtype=object)

# %%
df_drink.item_name.nunique()
# Out:
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df[df.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
df[df.item_name=='Chicken Bowl'].choice_description
# Out:
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5       [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 13      [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 19      [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 26      [Roasted Chili Corn Salsa (Medium), [Pinto Bea...
#                               ...
# 4590    [Roasted Chili Corn Salsa, [Rice, Black Beans,...
# 4591    [Tomatillo Red Chili Salsa, [Rice, Black Beans...
# 4595    [Tomatillo Green Chili Salsa, [Rice, Black Bea...
# 4599        [Roasted Chili Corn Salsa, [Cheese, Lettuce]]
# 4604    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...
# Name: choice_description, Length: 726, dtype: object

# %%
df[df.item_name=='Chicken Bowl'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa, [Fajita Vegetables, Rice]]                                             17
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                      14
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]           14
# [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream, Lettuce]]                                   13
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]                                           13
#                                                                                             ..
# [Tomatillo Green Chili Salsa, [Rice, Cheese, Guacamole]]                                     1
# [Tomatillo-Green Chili Salsa (Medium), [Black Beans, Rice, Cheese, Sour Cream]]              1
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Sour Cream, Guacamole]]                      1
# [Fresh Tomato Salsa (Mild), [Black Beans, Rice, Cheese, Sour Cream, Guacamole, Lettuce]]     1
# ...

# %%
df[df.item_name=='Chicken Bowl'].choice_description.nunique()
# Out:
# 348

# %%
df.dropna(inplace=True)

# %%
df[df.item_name=='Chicken Bowl'].choice_description.nunique()
# Out:
# 348

# %%
df[df.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_price <10) & (df.item_name=='Steak Burrito')]
# Out:
#       order_id  quantity      item_name  \
# 9            5         1  Steak Burrito
# 31          16         1  Steak Burrito
# 46          21         1  Steak Burrito
# 48          22         1  Steak Burrito
# 50          23         1  Steak Burrito
# ...        ...       ...            ...
# 4446      1772         1  Steak Burrito
# 4473      1783         1  Steak Burrito
# 4508      1793         1  Steak Burrito
# 4536      1803         1  Steak Burrito
# 4546      1807         1  Steak Burrito
#
#                                      choice_description  item_price
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...        8.99
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...        8.99
# 48    [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...        8.99
# 50    [Roasted Chili Corn Salsa (Medium), [Rice, Faj...        8.99
# ...                                                 ...         ...
# ...

# %%
df[(df.item_price <10) & (df.item_name=='Steak Burrito')].sort_values(['item_price'])
# Out:
#       order_id  quantity      item_name  \
# 1272       517         1  Steak Burrito
# 3501      1406         1  Steak Burrito
# 728        301         1  Steak Burrito
# 3530      1419         1  Steak Burrito
# 3532      1420         1  Steak Burrito
# ...        ...       ...            ...
# 1911       772         1  Steak Burrito
# 1858       753         1  Steak Burrito
# 1771       715         1  Steak Burrito
# 2467       979         1  Steak Burrito
# 4546      1807         1  Steak Burrito
#
#                                      choice_description  item_price
# 1272  [Tomatillo Red Chili (Hot), [Lettuce, Rice, So...        8.69
# 3501                  [[Lettuce, Fajita Veggies, Rice]]        8.69
# 728   [Roasted Chili Corn (Medium), [Sour Cream, Che...        8.69
# 3530  [Fresh Tomato (Mild), [Lettuce, Pinto Beans, R...        8.69
# 3532                  [[Lettuce, Fajita Veggies, Rice]]        8.69
# ...                                                 ...         ...
# ...

# %%
movies=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv')
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies[(movies.star_rating>=8) & (movies.content_rating=='PG-13')]
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 13           8.8                                       Forrest Gump
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 25           8.6                                  Life Is Beautiful
# 26           8.6                       Once Upon a Time in the West
# 43           8.5                              The Dark Knight Rises
# 53           8.5                                       The Prestige
# 60           8.5                                           3 Idiots
# 69           8.4                                  Princess Mononoke
# ...

# %%
a=movies[(movies.star_rating>=8) & (movies.content_rating=='PG-13')].sort_values(['duration'])
a
# Out:
#      star_rating                                              title  \
# 175          8.2                                      Touch of Evil
# 305          8.0                                         Persepolis
# 232          8.1                                  Chungking Express
# 356          8.0                                         The Artist
# 279          8.1                    The Perks of Being a Wallflower
# 370          8.0                             Hannah and Her Sisters
# 314          8.0                            Crimes and Misdemeanors
# 379          8.0                                Edward Scissorhands
# 191          8.2                                    The Sixth Sense
# 286          8.1                  The Diving Bell and the Butterfly
# 391          8.0                                   Edge of Tomorrow
# 209          8.1                                 The Imitation Game
# 240          8.1                               The Bourne Ultimatum
# ...

# %%
a[a.actors_list.str.contains('Leonardo DiCaprio')].title
# Out:
# 340    Catch Me If You Can
# 11               Inception
# Name: title, dtype: object

# %%
movies[movies.actors_list.str.contains('Elijah Wood', 'Ian McKellen')].sort_values(['duration'])
# Out:
#      star_rating                                              title  \
# 868          7.5                          Everything Is Illuminated
# 830          7.5                             Green Street Hooligans
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 7            8.9      The Lord of the Rings: The Return of the King
#
#     content_rating      genre  duration  \
# 868          PG-13     Comedy       106
# 830              R      Crime       109
# 10           PG-13  Adventure       178
# 14           PG-13  Adventure       179
# 7            PG-13  Adventure       201
#
#                                            actors_list
# 868  [u'Elijah Wood', u'Eugene Hutz', u'Boris Leskin']
# 830  [u'Elijah Wood', u'Charlie Hunnam', u'Claire F...
# 10   [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 14   [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# ...

# %%
movies[movies.actors_list.str.contains('Tom Cruise')].sort_values(['duration'])
# Out:
#      star_rating                                              title  \
# 391          8.0                                   Edge of Tomorrow
# 797          7.6                                         Collateral
# 779          7.6  Interview with the Vampire: The Vampire Chroni...
# 325          8.0                                           Rain Man
# 716          7.6                                     A Few Good Men
# 686          7.7                                    Minority Report
# 613          7.7                                   The Last Samurai
# 318          8.0                                           Magnolia
#
#     content_rating   genre  duration  \
# 391          PG-13  Action       113
# 797              R   Crime       120
# 779              R  Horror       123
# 325              R   Drama       133
# 716              R   Drama       138
# 686          PG-13  Action       145
# 613              R  Action       154
# 318              R   Drama       188
#
# ...

# %%
movies[(movies.actors_list.str.contains('Elijah Wood')) &(movies.actors_list.str.contains('Ian McKellen')) ].sort_values(['duration'])
# Out:
#     star_rating                                              title  \
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 14          8.8              The Lord of the Rings: The Two Towers
# 7           8.9      The Lord of the Rings: The Return of the King
#
#    content_rating      genre  duration  \
# 10          PG-13  Adventure       178
# 14          PG-13  Adventure       179
# 7           PG-13  Adventure       201
#
#                                           actors_list
# 10  [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 14  [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 7   [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...

# %%
movies[movies.actors_list.str.contains('Tom Cruise')].sort_values(['duration','star_rating'],ascending=(True,False))
# Out:
#      star_rating                                              title  \
# 391          8.0                                   Edge of Tomorrow
# 797          7.6                                         Collateral
# 779          7.6  Interview with the Vampire: The Vampire Chroni...
# 325          8.0                                           Rain Man
# 716          7.6                                     A Few Good Men
# 686          7.7                                    Minority Report
# 613          7.7                                   The Last Samurai
# 318          8.0                                           Magnolia
#
#     content_rating   genre  duration  \
# 391          PG-13  Action       113
# 797              R   Crime       120
# 779              R  Horror       123
# 325              R   Drama       133
# 716              R   Drama       138
# 686          PG-13  Action       145
# 613              R  Action       154
# 318              R   Drama       188
#
# ...

# %%
ufo=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv')
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18234              Capitola             NaN       TRIANGLE    CA
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').value_counts()
# Out:
# City                                 Colors Reported  Shape Reported  State  Time
# Rockford                             ORANGE           CIRCLE          IL     2/16/2000 21:30     2
# Jamestown                            GREEN            LIGHT           TN     11/16/1999 18:05    2
# Jamaica Estates                      BLUE             LIGHT           NY     12/26/1999 20:25    2
# Colorado Springs                     RED              LIGHT           CO     6/1/1995 1:00       2
# Walpole                              GREEN            FIREBALL        NH     12/26/2000 18:20    2
#                                                                                                 ..
# Grayling                             ORANGE           SPHERE          MI     6/12/1998 10:30     1
#                                                                              8/9/1998 0:00       1
# Green Bay                            ORANGE           LIGHT           WI     11/2/1997 18:50     1
# ...

# %%
drinks=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.beer_servings.min()
# Out:
# 0

# %%
drinks.beer_servings.max()
# Out:
# 376

# %%
drinks[drinks.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
drinks[drinks.continent=='Asia'].	beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').wine_servings.max()
# Out:
# continent
# Africa           233
# Asia             123
# Europe           370
# North America    100
# Oceania          212
# South America    221
# Name: wine_servings, dtype: int64

# %%
drinks.groupby('continent').wine_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          16.264151    0  233
# Asia             9.068182    0  123
# Europe         142.222222    0  370
# North America   24.521739    1  100
# Oceania         35.625000    0  212
# South America   62.416667    1  221
